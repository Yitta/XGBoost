# %% [markdown]
# # data exploration

# %%
import pandas as pd

# input file - dataset only when the pump is opening
file_directory = './sample data/output_3_files.csv'

# output file - without useless features (for modelling)
modelling_data_directory = './sample data/modelling_dataset.csv'

# %%
df = pd.read_csv(file_directory)
df.shape
# Out:
# (2769, 399)

# %%
df.head(10)
# Out:
#   measurement_result_date  average_result_value  statistic_type asset_code  \
# 0     2016-12-01 00:00:00                1.4572  Snap (Current)      WQM01
# 1     2016-12-01 00:15:00                1.4560  Snap (Current)      WQM01
# 2     2016-12-01 00:30:00                1.4540  Snap (Current)      WQM01
# 3     2016-12-01 00:45:00                1.4432  Snap (Current)      WQM01
# 4     2016-12-01 01:00:00                1.4306  Snap (Current)      WQM01
# 5     2016-12-01 01:15:00                1.4292  Snap (Current)      WQM01
# 6     2016-12-01 01:30:00                1.4324  Snap (Current)      WQM01
# 7     2016-12-01 01:45:00                1.4230  Snap (Current)      WQM01
# 8     2016-12-01 02:00:00                1.4198  Snap (Current)      WQM01
# 9     2016-12-01 02:15:00                1.4128  Snap (Current)      WQM01
#
#   facility_code  Average Result Value Measurement_Result_Date_Minute_15  \
# ...

# %% [markdown]
# ## 2 node id in feature dataset

# %%
filename = "./sample data/feature.csv"
df_feature = pd.read_csv(filename, parse_dates=['timestamp'])
df_feature['node_id'].describe()
# Out:
# count    17282.000000
# mean     36573.000000
# std       5335.154358
# min      31238.000000
# 25%      31238.000000
# 50%      36573.000000
# 75%      41908.000000
# max      41908.000000
# Name: node_id, dtype: float64

# %%
features_32138 = df_feature.loc[df_feature['node_id']==31238]
features_41908 = df_feature.loc[df_feature['node_id']==41908]

# %% [markdown]
# ### - 判断二个node的数据是否有不同

# %%
features_32138['zone_flow_hist_0min'].describe()
# Out:
# count    8641.000000
# mean        2.408029
# std         1.825553
# min         0.001786
# 25%         0.743492
# 50%         2.306323
# 75%         3.631476
# max        10.305820
# Name: zone_flow_hist_0min, dtype: float64

# %%
features_32138['res_cl_hist_0min'].describe()
# Out:
# count    8641.000000
# mean        1.475214
# std         0.078918
# min         1.254849
# 25%         1.421894
# 50%         1.477509
# 75%         1.528201
# max         1.734405
# Name: res_cl_hist_0min, dtype: float64

# %%
features_41908['travel_time_hrs_nom'].describe()
# Out:
# count    8.641000e+03
# mean     2.583436e+01
# std      3.048405e-12
# min      2.583436e+01
# 25%      2.583436e+01
# 50%      2.583436e+01
# 75%      2.583436e+01
# max      2.583436e+01
# Name: travel_time_hrs_nom, dtype: float64

# %%
features_41908['travel_time_hrs_nom'].describe()
# Out:
# count    8.641000e+03
# mean     2.583436e+01
# std      3.048405e-12
# min      2.583436e+01
# 25%      2.583436e+01
# 50%      2.583436e+01
# 75%      2.583436e+01
# max      2.583436e+01
# Name: travel_time_hrs_nom, dtype: float64

# %% [markdown]
# # data cleaning

# %%
df.describe()
# Out:
#        average_result_value  Average Result Value  zone_flow_hist_0min  \
# count           2769.000000           2769.000000          2769.000000
# mean               1.276345              1.005778             1.152518
# std                0.139701              0.075809             1.743221
# min                0.745000              1.000000             0.001786
# 25%                1.197000              1.000000             0.163542
# 50%                1.290200              1.000000             0.468314
# 75%                1.369600              1.000000             1.315512
# max                1.617200              2.000000            10.305820
#
#        zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# count           2769.000000           2769.000000           2769.000000
# mean               1.250574              1.352919              1.458963
# std                1.821041              1.887563              1.944308
# ...

# %%
df.shape
# Out:
# (2769, 399)

# %% [markdown]
# * average_result_value: label
# * Average Result Value: pump speed - sum 3 nodes
# * zone_flow_hist_0min: flow speed (record in every 15mins - total: 2 days)
# * res_cl_hist_0min: upstream result history of chlorine (record in every 15mins - total: 2 days)
# * res_temperature

# %%
feature_droped = ['zone_id', 'node_id', 'timestamp', 'flow_nom', 'travel_time_hrs_nom', 'Measurement_Result_Date_Minute_15', 'facility_code', 'asset_code', 'statistic_type', 'measurement_result_date']
df_tem = df.drop(feature_droped ,axis=1)
df_tem.shape
# Out:
# (2769, 389)

# %%
df_tem.head(5)
# Out:
#    average_result_value  Average Result Value  zone_flow_hist_0min  \
# 0                1.4572                     1             0.537967
# 1                1.4560                     1             0.374730
# 2                1.4540                     1             0.228371
# 3                1.4432                     1             0.169935
# 4                1.4306                     1             0.172979
#
#    zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# 0              0.677703              0.838600              0.992196
# 1              0.537967              0.677703              0.838600
# 2              0.374730              0.537967              0.677703
# 3              0.228371              0.374730              0.537967
# 4              0.169935              0.228371              0.374730
#
#    zone_flow_hist_60min  zone_flow_hist_75min  zone_flow_hist_90min  \
# 0              1.086506              1.151700              1.272814
# ...

# %% [markdown]
# ## output training data

# %% [markdown]
# ### - without timestamp

# %%
df_tem.to_csv(modelling_data_directory, index=None)

# %%
df_tem.describe()
# Out:
#        average_result_value  Average Result Value  zone_flow_hist_0min  \
# count           2769.000000           2769.000000          2769.000000
# mean               1.276345              1.005778             1.152518
# std                0.139701              0.075809             1.743221
# min                0.745000              1.000000             0.001786
# 25%                1.197000              1.000000             0.163542
# 50%                1.290200              1.000000             0.468314
# 75%                1.369600              1.000000             1.315512
# max                1.617200              2.000000            10.305820
#
#        zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# count           2769.000000           2769.000000           2769.000000
# mean               1.250574              1.352919              1.458963
# std                1.821041              1.887563              1.944308
# ...
