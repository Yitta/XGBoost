# %% [markdown]
# # data exploration

# %%
import pandas as pd

# input file - dataset only when the pump is opening
file_directory = './sample data/output_all_4_data.csv'

# output file - without useless features (for modelling)
modelling_data_directory = './sample data/modelling_dataset_levels.csv'
modelling_diff_data_directory = './sample data/modelling_diff_dataset_levels.csv'
modelling_only_open_diff_data_directory = './sample data/modelling_only_open_diff_dataset_levels.csv'

# %%
df = pd.read_csv(file_directory, parse_dates=['measurement_result_date'])
df.shape
# Out:
# (8640, 400)

# %%
df = df.rename(columns={'Average Result Value': 'pump_average_speed_sum'})

# %%
df.head(5)
# Out:
#   measurement_result_date  average_result_value  statistic_type asset_code  \
# 0     2016-12-01 00:00:00                1.4572  Snap (Current)      WQM01
# 1     2016-12-01 00:15:00                1.4560  Snap (Current)      WQM01
# 2     2016-12-01 00:30:00                1.4540  Snap (Current)      WQM01
# 3     2016-12-01 00:45:00                1.4432  Snap (Current)      WQM01
# 4     2016-12-01 01:00:00                1.4306  Snap (Current)      WQM01
#
#   facility_code  pump_average_speed_sum Measurement_Result_Date_Minute_15  \
# 0        WQ0118                       1               2016-12-01 00:00:00
# 1        WQ0118                       1               2016-12-01 00:15:00
# 2        WQ0118                       1               2016-12-01 00:30:00
# 3        WQ0118                       1               2016-12-01 00:45:00
# 4        WQ0118                       1               2016-12-01 01:00:00
#
#    zone_flow_hist_0min  zone_flow_hist_15min  zone_flow_hist_30min  \
# 0             0.537967              0.677703              0.838600
# 1             0.374730              0.537967              0.677703
# 2             0.228371              0.374730              0.537967
# 3             0.169935              0.228371              0.374730
# 4             0.172979              0.169935              0.228371
#
#       ...       res_cl_hist_2850min  res_cl_hist_2865min  res_cl_hist_2880min  \
# 0     ...                  1.709118             1.707396             1.708366
# 1     ...                  1.711658             1.709118             1.707396
# 2     ...                  1.714862             1.711658             1.709118
# 3     ...                  1.718593             1.714862             1.711658
# 4     ...                  1.720893             1.718593             1.714862
#
#    res_temperature  travel_time_hrs_nom  flow_nom            timestamp  \
# 0             17.4             2.789096  1.931739  2016-12-01 00:00:00
# 1             17.4             2.789096  1.931739  2016-12-01 00:15:00
# 2             17.4             2.789096  1.931739  2016-12-01 00:30:00
# 3             17.4             2.789096  1.931739  2016-12-01 00:45:00
# 4             17.4             2.789096  1.931739  2016-12-01 01:00:00
#
#    node_id                 zone_id  water_level
# 0  31238.0  engadine_rem_flow_zone        58.92
# 1  31238.0  engadine_rem_flow_zone        59.53
# 2  31238.0  engadine_rem_flow_zone        60.14
# 3  31238.0  engadine_rem_flow_zone        60.75
# 4  31238.0  engadine_rem_flow_zone        61.35
#
# [5 rows x 400 columns]

# %% [markdown]
# # data cleaning

# %%
df.describe()
# Out:
#        average_result_value  pump_average_speed_sum  zone_flow_hist_0min  \
# count           8640.000000             8640.000000          8640.000000
# mean               1.182842                0.322222             2.408267
# std                0.148628                0.471301             1.825524
# min                0.745000                0.000000             0.001786
# 25%                1.076400                0.000000             0.744151
# 50%                1.179800                0.000000             2.306694
# 75%                1.288400                1.000000             3.631555
# max                1.617200                2.000000            10.305820
#
#        zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# count           8640.000000           8640.000000           8640.000000
# mean               2.408307              2.408366              2.408444
# std                1.825483              1.825424              1.825349
# min                0.001786              0.001786              0.001786
# 25%                0.744151              0.744494              0.745410
# 50%                2.306694              2.306694              2.306694
# 75%                3.631555              3.631555              3.631555
# max               10.305820             10.305820             10.305820
#
#        zone_flow_hist_60min  zone_flow_hist_75min  zone_flow_hist_90min  \
# count           8640.000000           8640.000000           8640.000000
# mean               2.408531              2.408613              2.408670
# std                1.825267              1.825195              1.825153
# min                0.001786              0.001786              0.001786
# 25%                0.745831              0.746226              0.746226
# 50%                2.306694              2.306694              2.306694
# 75%                3.631555              3.631555              3.631555
# max               10.305820             10.305820             10.305820
#
#        zone_flow_hist_105min     ...       res_cl_hist_2820min  \
# count            8640.000000     ...               8640.000000
# mean                2.408700     ...                  1.480150
# std                 1.825136     ...                  0.079535
# min                 0.001786     ...                  1.254849
# 25%                 0.746226     ...                  1.428040
# 50%                 2.306694     ...                  1.482050
# 75%                 3.631555     ...                  1.532148
# max                10.305820     ...                  1.735576
#
#        res_cl_hist_2835min  res_cl_hist_2850min  res_cl_hist_2865min  \
# count          8640.000000          8640.000000          8640.000000
# mean              1.480194             1.480239             1.480283
# std               0.079557             0.079579             0.079599
# min               1.254849             1.254849             1.254849
# 25%               1.428064             1.428073             1.428096
# 50%               1.482063             1.482069             1.482085
# 75%               1.532177             1.532192             1.532228
# max               1.735576             1.735576             1.735576
#
#        res_cl_hist_2880min  res_temperature  travel_time_hrs_nom  \
# count          8640.000000      8640.000000         8.640000e+03
# mean              1.480327        21.732778         2.789096e+00
# std               0.079619         1.876411         1.625461e-13
# min               1.254849        17.400000         2.789096e+00
# 25%               1.428167        20.650000         2.789096e+00
# 50%               1.482119        22.350000         2.789096e+00
# 75%               1.532244        22.950000         2.789096e+00
# max               1.735576        24.550000         2.789096e+00
#
#            flow_nom  node_id  water_level
# count  8.640000e+03   8640.0  8640.000000
# mean   1.931739e+00  31238.0    61.453346
# std    2.686895e-13      0.0     5.311319
# min    1.931739e+00  31238.0    51.830000
# 25%    1.931739e+00  31238.0    56.970000
# 50%    1.931739e+00  31238.0    61.360000
# 75%    1.931739e+00  31238.0    65.942500
# max    1.931739e+00  31238.0    75.090000
#
# [8 rows x 393 columns]

# %% [markdown]
# * average_result_value: label
# * Average Result Value: pump speed - sum 3 nodes
# * zone_flow_hist_0min: flow speed (record in every 15mins - total: 2 days)
# * res_cl_hist_0min: upstream result history of chlorine (record in every 15mins - total: 2 days)
# * res_temperature
# * water_level

# %%
feature_droped = ['zone_id', 'node_id', 'timestamp', 'flow_nom', 'travel_time_hrs_nom', 'Measurement_Result_Date_Minute_15', 'facility_code', 'asset_code', 'statistic_type']
df_tem = df.drop(feature_droped ,axis=1)
df_tem.shape
# Out:
# (8640, 391)

# %%
df_tem.head(5)
# Out:
#   measurement_result_date  average_result_value  pump_average_speed_sum  \
# 0     2016-12-01 00:00:00                1.4572                       1
# 1     2016-12-01 00:15:00                1.4560                       1
# 2     2016-12-01 00:30:00                1.4540                       1
# 3     2016-12-01 00:45:00                1.4432                       1
# 4     2016-12-01 01:00:00                1.4306                       1
#
#    zone_flow_hist_0min  zone_flow_hist_15min  zone_flow_hist_30min  \
# 0             0.537967              0.677703              0.838600
# 1             0.374730              0.537967              0.677703
# 2             0.228371              0.374730              0.537967
# 3             0.169935              0.228371              0.374730
# 4             0.172979              0.169935              0.228371
#
#    zone_flow_hist_45min  zone_flow_hist_60min  zone_flow_hist_75min  \
# 0              0.992196              1.086506              1.151700
# 1              0.838600              0.992196              1.086506
# 2              0.677703              0.838600              0.992196
# 3              0.537967              0.677703              0.838600
# 4              0.374730              0.537967              0.677703
#
#    zone_flow_hist_90min     ...       res_cl_hist_2775min  \
# 0              1.272814     ...                  1.721563
# 1              1.151700     ...                  1.723967
# 2              1.086506     ...                  1.727027
# 3              0.992196     ...                  1.729251
# 4              0.838600     ...                  1.730591
#
#    res_cl_hist_2790min  res_cl_hist_2805min  res_cl_hist_2820min  \
# 0             1.720893             1.718593             1.714862
# 1             1.721563             1.720893             1.718593
# 2             1.723967             1.721563             1.720893
# 3             1.727027             1.723967             1.721563
# 4             1.729251             1.727027             1.723967
#
#    res_cl_hist_2835min  res_cl_hist_2850min  res_cl_hist_2865min  \
# 0             1.711658             1.709118             1.707396
# 1             1.714862             1.711658             1.709118
# 2             1.718593             1.714862             1.711658
# 3             1.720893             1.718593             1.714862
# 4             1.721563             1.720893             1.718593
#
#    res_cl_hist_2880min  res_temperature  water_level
# 0             1.708366             17.4        58.92
# 1             1.707396             17.4        59.53
# 2             1.709118             17.4        60.14
# 3             1.711658             17.4        60.75
# 4             1.714862             17.4        61.35
#
# [5 rows x 391 columns]

# %% [markdown]
# # Data pre-processing
# * change label to diff value
# * 19/09/2017
#  - get diff in time
#  - 25/09/2018

# %%
# get diff in label
df_label_diff = df_tem['average_result_value'].diff()
df_label_diff[8635:]
# Out:
# 8635   -0.0082
# 8636    0.0032
# 8637    0.0000
# 8638    0.0000
# 8639    0.1630
# Name: average_result_value, dtype: float64

# %%
# label describe
df_label_diff.describe()
# Out:
# count    8639.000000
# mean       -0.000025
# std         0.041528
# min        -0.370000
# 25%        -0.007600
# 50%        -0.002000
# 75%         0.003200
# max         0.419000
# Name: average_result_value, dtype: float64

# %%
# form new diff dataset with all data
df_tem_1 = df_tem.drop(['average_result_value'], axis=1)
df_diff = pd.concat([df_tem_1, df_label_diff], axis=1)
df_diff.shape
# Out:
# (8640, 391)

# %%
df_diff.head(5)
# Out:
#   measurement_result_date  pump_average_speed_sum  zone_flow_hist_0min  \
# 0     2016-12-01 00:00:00                       1             0.537967
# 1     2016-12-01 00:15:00                       1             0.374730
# 2     2016-12-01 00:30:00                       1             0.228371
# 3     2016-12-01 00:45:00                       1             0.169935
# 4     2016-12-01 01:00:00                       1             0.172979
#
#    zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# 0              0.677703              0.838600              0.992196
# 1              0.537967              0.677703              0.838600
# 2              0.374730              0.537967              0.677703
# 3              0.228371              0.374730              0.537967
# 4              0.169935              0.228371              0.374730
#
#    zone_flow_hist_60min  zone_flow_hist_75min  zone_flow_hist_90min  \
# 0              1.086506              1.151700              1.272814
# 1              0.992196              1.086506              1.151700
# 2              0.838600              0.992196              1.086506
# 3              0.677703              0.838600              0.992196
# 4              0.537967              0.677703              0.838600
#
#    zone_flow_hist_105min          ...           res_cl_hist_2790min  \
# 0               1.529712          ...                      1.720893
# 1               1.272814          ...                      1.721563
# 2               1.151700          ...                      1.723967
# 3               1.086506          ...                      1.727027
# 4               0.992196          ...                      1.729251
#
#    res_cl_hist_2805min  res_cl_hist_2820min  res_cl_hist_2835min  \
# 0             1.718593             1.714862             1.711658
# 1             1.720893             1.718593             1.714862
# 2             1.721563             1.720893             1.718593
# 3             1.723967             1.721563             1.720893
# 4             1.727027             1.723967             1.721563
#
#    res_cl_hist_2850min  res_cl_hist_2865min  res_cl_hist_2880min  \
# 0             1.709118             1.707396             1.708366
# 1             1.711658             1.709118             1.707396
# 2             1.714862             1.711658             1.709118
# 3             1.718593             1.714862             1.711658
# 4             1.720893             1.718593             1.714862
#
#    res_temperature  water_level  average_result_value
# 0             17.4        58.92                   NaN
# 1             17.4        59.53               -0.0012
# 2             17.4        60.14               -0.0020
# 3             17.4        60.75               -0.0108
# 4             17.4        61.35               -0.0126
#
# [5 rows x 391 columns]

# %%
# form new diff dataset with all data
# - without invalid first line

df_diff.drop([0], inplace=True)
df_diff.head(5)
# Out:
#   measurement_result_date  pump_average_speed_sum  zone_flow_hist_0min  \
# 1     2016-12-01 00:15:00                       1             0.374730
# 2     2016-12-01 00:30:00                       1             0.228371
# 3     2016-12-01 00:45:00                       1             0.169935
# 4     2016-12-01 01:00:00                       1             0.172979
# 5     2016-12-01 01:15:00                       1             0.189868
#
#    zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# 1              0.537967              0.677703              0.838600
# 2              0.374730              0.537967              0.677703
# 3              0.228371              0.374730              0.537967
# 4              0.169935              0.228371              0.374730
# 5              0.172979              0.169935              0.228371
#
#    zone_flow_hist_60min  zone_flow_hist_75min  zone_flow_hist_90min  \
# 1              0.992196              1.086506              1.151700
# 2              0.838600              0.992196              1.086506
# 3              0.677703              0.838600              0.992196
# 4              0.537967              0.677703              0.838600
# 5              0.374730              0.537967              0.677703
#
#    zone_flow_hist_105min          ...           res_cl_hist_2790min  \
# 1               1.272814          ...                      1.721563
# 2               1.151700          ...                      1.723967
# 3               1.086506          ...                      1.727027
# 4               0.992196          ...                      1.729251
# 5               0.838600          ...                      1.730591
#
#    res_cl_hist_2805min  res_cl_hist_2820min  res_cl_hist_2835min  \
# 1             1.720893             1.718593             1.714862
# 2             1.721563             1.720893             1.718593
# 3             1.723967             1.721563             1.720893
# 4             1.727027             1.723967             1.721563
# 5             1.729251             1.727027             1.723967
#
#    res_cl_hist_2850min  res_cl_hist_2865min  res_cl_hist_2880min  \
# 1             1.711658             1.709118             1.707396
# 2             1.714862             1.711658             1.709118
# 3             1.718593             1.714862             1.711658
# 4             1.720893             1.718593             1.714862
# 5             1.721563             1.720893             1.718593
#
#    res_temperature  water_level  average_result_value
# 1             17.4        59.53               -0.0012
# 2             17.4        60.14               -0.0020
# 3             17.4        60.75               -0.0108
# 4             17.4        61.35               -0.0126
# 5             17.4        61.97               -0.0014
#
# [5 rows x 391 columns]

# %% [markdown]
# # Output only open dataset

# %%
# only open dataset
df_tem_only_open = df_diff.loc[df_diff['pump_average_speed_sum']>0]
df_tem_only_open.drop(['measurement_result_date'], axis=1).head(3)
# Out:
#    pump_average_speed_sum  zone_flow_hist_0min  zone_flow_hist_15min  \
# 1                       1             0.374730              0.537967
# 2                       1             0.228371              0.374730
# 3                       1             0.169935              0.228371
#
#    zone_flow_hist_30min  zone_flow_hist_45min  zone_flow_hist_60min  \
# 1              0.677703              0.838600              0.992196
# 2              0.537967              0.677703              0.838600
# 3              0.374730              0.537967              0.677703
#
#    zone_flow_hist_75min  zone_flow_hist_90min  zone_flow_hist_105min  \
# 1              1.086506              1.151700               1.272814
# 2              0.992196              1.086506               1.151700
# 3              0.838600              0.992196               1.086506
#
#    zone_flow_hist_120min          ...           res_cl_hist_2790min  \
# 1               1.529712          ...                      1.721563
# 2               1.272814          ...                      1.723967
# 3               1.151700          ...                      1.727027
#
#    res_cl_hist_2805min  res_cl_hist_2820min  res_cl_hist_2835min  \
# 1             1.720893             1.718593             1.714862
# 2             1.721563             1.720893             1.718593
# 3             1.723967             1.721563             1.720893
#
#    res_cl_hist_2850min  res_cl_hist_2865min  res_cl_hist_2880min  \
# 1             1.711658             1.709118             1.707396
# 2             1.714862             1.711658             1.709118
# 3             1.718593             1.714862             1.711658
#
#    res_temperature  water_level  average_result_value
# 1             17.4        59.53               -0.0012
# 2             17.4        60.14               -0.0020
# 3             17.4        60.75               -0.0108
#
# [3 rows x 390 columns]

# %%
# Output only open dataset
df_tem_only_open.drop(['measurement_result_date'], axis=1).to_csv(modelling_only_open_diff_data_directory, index=None)

# %% [markdown]
# # Output open data with 2 hours close

# %%
df_tem_only_open.head(4)
# Out:
#   measurement_result_date  pump_average_speed_sum  zone_flow_hist_0min  \
# 1     2016-12-01 00:15:00                       1             0.374730
# 2     2016-12-01 00:30:00                       1             0.228371
# 3     2016-12-01 00:45:00                       1             0.169935
# 4     2016-12-01 01:00:00                       1             0.172979
#
#    zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# 1              0.537967              0.677703              0.838600
# 2              0.374730              0.537967              0.677703
# 3              0.228371              0.374730              0.537967
# 4              0.169935              0.228371              0.374730
#
#    zone_flow_hist_60min  zone_flow_hist_75min  zone_flow_hist_90min  \
# 1              0.992196              1.086506              1.151700
# 2              0.838600              0.992196              1.086506
# 3              0.677703              0.838600              0.992196
# 4              0.537967              0.677703              0.838600
#
#    zone_flow_hist_105min    ...      res_cl_hist_2805min  res_cl_hist_2820min  \
# 1               1.272814    ...                 1.720893             1.718593
# 2               1.151700    ...                 1.721563             1.720893
# 3               1.086506    ...                 1.723967             1.721563
# 4               0.992196    ...                 1.727027             1.723967
#
#    res_cl_hist_2835min  res_cl_hist_2850min  res_cl_hist_2865min  \
# 1             1.714862             1.711658             1.709118
# 2             1.718593             1.714862             1.711658
# 3             1.720893             1.718593             1.714862
# 4             1.721563             1.720893             1.718593
#
#    res_cl_hist_2880min  res_temperature  water_level  average_result_value  \
# 1             1.707396             17.4        59.53               -0.0012
# 2             1.709118             17.4        60.14               -0.0020
# 3             1.711658             17.4        60.75               -0.0108
# 4             1.714862             17.4        61.35               -0.0126
#
#    time_diff
# 1        NaT
# 2   00:15:00
# 3   00:15:00
# 4   00:15:00
#
# [4 rows x 392 columns]

# %%
df_tem_only_open.shape
# Out:
# (2767, 392)

# %%
# get diff in time
df_time_diff = df_tem_only_open['measurement_result_date'].diff()
df_tem_only_open['time_diff'] = df_time_diff
df_tem_only_open.head(5)
# Out:
# /Users/yuhan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   measurement_result_date  pump_average_speed_sum  zone_flow_hist_0min  \
# 1     2016-12-01 00:15:00                       1             0.374730
# 2     2016-12-01 00:30:00                       1             0.228371
# 3     2016-12-01 00:45:00                       1             0.169935
# 4     2016-12-01 01:00:00                       1             0.172979
# 5     2016-12-01 01:15:00                       1             0.189868
#
#    zone_flow_hist_15min  zone_flow_hist_30min  zone_flow_hist_45min  \
# 1              0.537967              0.677703              0.838600
# 2              0.374730              0.537967              0.677703
# 3              0.228371              0.374730              0.537967
# 4              0.169935              0.228371              0.374730
# 5              0.172979              0.169935              0.228371
#
#    zone_flow_hist_60min  zone_flow_hist_75min  zone_flow_hist_90min  \
# 1              0.992196              1.086506              1.151700
# 2              0.838600              0.992196              1.086506
# 3              0.677703              0.838600              0.992196
# 4              0.537967              0.677703              0.838600
# 5              0.374730              0.537967              0.677703
#
#    zone_flow_hist_105min    ...      res_cl_hist_2805min  res_cl_hist_2820min  \
# 1               1.272814    ...                 1.720893             1.718593
# 2               1.151700    ...                 1.721563             1.720893
# 3               1.086506    ...                 1.723967             1.721563
# 4               0.992196    ...                 1.727027             1.723967
# 5               0.838600    ...                 1.729251             1.727027
#
#    res_cl_hist_2835min  res_cl_hist_2850min  res_cl_hist_2865min  \
# 1             1.714862             1.711658             1.709118
# 2             1.718593             1.714862             1.711658
# 3             1.720893             1.718593             1.714862
# 4             1.721563             1.720893             1.718593
# 5             1.723967             1.721563             1.720893
#
#    res_cl_hist_2880min  res_temperature  water_level  average_result_value  \
# 1             1.707396             17.4        59.53               -0.0012
# 2             1.709118             17.4        60.14               -0.0020
# 3             1.711658             17.4        60.75               -0.0108
# 4             1.714862             17.4        61.35               -0.0126
# 5             1.718593             17.4        61.97               -0.0014
# freq                        2
# first     2016-12-01 00:15:00
# last      2017-02-28 23:45:00
# Name: measurement_result_date, dtype: object

# %%
# 构建完整，可用于检查的数据 （包含时间戳及时间差）
df_tem_series_result.head(5)
# Out:
#    average_result_value measurement_result_date  pump_average_speed_sum  \
# 1               -0.0012     2016-12-01 00:15:00                       1
# 2               -0.0020     2016-12-01 00:30:00                       1
# 3               -0.0108     2016-12-01 00:45:00                       1
# 4               -0.0126     2016-12-01 01:00:00                       1
# 5               -0.0014     2016-12-01 01:15:00                       1
#
#    res_cl_hist_0min  res_cl_hist_1005min  res_cl_hist_1020min  \
# 1          1.534634             1.586609             1.587583
# 2          1.536314             1.583170             1.586609
# 3          1.538072             1.579295             1.583170
# 4          1.538999             1.576564             1.579295
# 5          1.538945             1.574967             1.576564
#
#    res_cl_hist_1035min  res_cl_hist_1050min  res_cl_hist_105min  \
# 1             1.586375             1.584198            1.512596
# 2             1.587583             1.586375            1.517226
# 3             1.586609             1.587583            1.520581
# 4             1.583170             1.586609            1.522850
# 5             1.579295             1.583170            1.525727
#
#    res_cl_hist_1065min          ...            zone_flow_hist_870min  \
# 1             1.581583          ...                         3.191080
# 2             1.584198          ...                         3.020517
# 3             1.586375          ...                         2.897907
# 4             1.587583          ...                         2.788926
# 5             1.586609          ...                         2.712861
#
#    zone_flow_hist_885min  zone_flow_hist_900min  zone_flow_hist_90min  \
# 1               3.500224               3.997968              1.151700
# 2               3.191080               3.500224              1.086506
# 3               3.020517               3.191080              0.992196
# 4               2.897907               3.020517              0.838600
# 5               2.788926               2.897907              0.677703
#
#    zone_flow_hist_915min  zone_flow_hist_930min  zone_flow_hist_945min  \
# 1               4.652041               5.138618               5.320497
# 2               3.997968               4.652041               5.138618
# 3               3.500224               3.997968               4.652041
# 4               3.191080               3.500224               3.997968
# 5               3.020517               3.191080               3.500224
#
#    zone_flow_hist_960min  zone_flow_hist_975min  zone_flow_hist_990min
# 1               5.347042               5.347777               5.349607
# 2               5.320497               5.347042               5.347777
# 3               5.138618               5.320497               5.347042
# 4               4.652041               5.138618               5.320497
# 5               3.997968               4.652041               5.138618
#
# [5 rows x 392 columns]

# %%
df_tem_series_result.drop_duplicates(['measurement_result_date']).shape
# Out:
# (3587, 392)

# %%
feature_drop = ['measurement_result_date', 'time_diff']
df_series_result = df_tem_series_result.drop_duplicates(['measurement_result_date'])
df_series_result = df_series_result.sort_values(['measurement_result_date'])
df_series_result = df_series_result.drop(feature_drop, axis=1)

# %%
df_series_result.shape
# Out:
# (3587, 390)

# %%
# Output add 2h close dataset
df_series_result.to_csv(modelling_diff_data_directory, index=None)

# %% [markdown]
# ## 总数验证
# - 25/09/2018

# %%
# 所有 间隔 >15min 的数据 - 需添加 pump 关闭数据的地方
df_tem_only_open[df_tem_only_open['time_diff'] > datetime.timedelta(minutes=15)].shape
# Out:
# (116, 392)

# %%
# 间隔 >= 2h - 可以完整加入8个数据的地方
df_tem_only_open[df_tem_only_open['time_diff'] >= datetime.timedelta(hours=2)].shape
# Out:
# (95, 392)

# %%
# 15min < 间隔 < 2h - 加入数据少于8个的地方
df_tem_only_open[(df_tem_only_open['time_diff'] > datetime.timedelta(minutes=15))&(df_tem_only_open['time_diff'] < datetime.timedelta(hours=2))].describe()
# Out:
#        pump_average_speed_sum  zone_flow_hist_0min  zone_flow_hist_15min  \
# count                    21.0            21.000000             21.000000
# mean                      1.0             1.809396              2.019425
# std                       0.0             0.356910              0.441173
# min                       1.0             1.402415              1.443857
# 25%                       1.0             1.505818              1.680799
# 50%                       1.0             1.713117              1.878389
# 75%                       1.0             2.037059              2.301147
# max                       1.0             2.582563              2.931976
#
#        zone_flow_hist_30min  zone_flow_hist_45min  zone_flow_hist_60min  \
# count             21.000000             21.000000             21.000000
# mean               2.337398              2.722455              3.075699
# std                0.601736              0.778764              0.917453
# min                1.505266              1.606591              1.827994
# 25%                1.888827              2.075523              2.439903
# 50%                2.201182              2.628134              3.037478
# 75%                2.603154              3.135774              3.531929
# max                3.509219              4.463693              5.463131
#
#        zone_flow_hist_75min  zone_flow_hist_90min  zone_flow_hist_105min  \
# count             21.000000             21.000000              21.000000
# mean               3.365465              3.711876               4.139437
# std                1.017434              1.114293               1.246116
# min                1.981700              2.080371               2.154950
# 25%                2.471810              3.019542               3.361535
# 50%                3.482653              3.888338               4.193175
# 75%                3.942386              4.205773               4.856076
# max                6.271031              7.003130               7.849941
#
#        zone_flow_hist_120min           ...            res_cl_hist_2805min  \
# count              21.000000           ...                      21.000000
# mean                4.598986           ...                       1.470546
# std                 1.387091           ...                       0.078120
# min                 2.388413           ...                       1.322531
# 25%                 3.612862           ...                       1.425314
# 50%                 4.517259           ...                       1.474725
# 75%                 5.511661           ...                       1.523639
# max                 8.715873           ...                       1.612625
#
#        res_cl_hist_2820min  res_cl_hist_2835min  res_cl_hist_2850min  \
# count            21.000000            21.000000            21.000000
# mean              1.467255             1.463945             1.460916
# std               0.077472             0.076014             0.075301
# min               1.326416             1.331549             1.331276
# 25%               1.419314             1.416561             1.413273
# 50%               1.473414             1.471420             1.460815
# 75%               1.522850             1.520581             1.516995
# max               1.612189             1.613258             1.615350
#
#        res_cl_hist_2865min  res_cl_hist_2880min  res_temperature  water_level  \
# count            21.000000            21.000000        21.000000    21.000000
# mean              1.457920             1.454312        21.714286    54.670476
# std               0.075659             0.076624         2.278878     0.426304
# min               1.332313             1.326505        17.400000    53.800000
# 25%               1.407319             1.400642        20.650000    54.390000
# 50%               1.447436             1.447490        22.350000    54.600000
# 75%               1.512596             1.510397        22.950000    55.050000
# max               1.615815             1.613884        24.550000    55.300000
#
#        average_result_value               time_diff
# count             21.000000                      21
# mean               0.001114  0 days 00:59:17.142857
# std                0.062845  0 days 00:25:18.740079
# min               -0.189800         0 days 00:30:00
# 25%               -0.010800         0 days 00:30:00
# 50%                0.000600         0 days 01:00:00
# 75%                0.007000         0 days 01:15:00
# max                0.183400         0 days 01:45:00
#
# [8 rows x 391 columns]
